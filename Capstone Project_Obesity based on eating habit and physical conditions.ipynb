# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
obesitydf = pd.read_csv('./ObesityDataSet_raw_and_data_sinthetic.csv')

# %%
obesitydf.shape
# Out:
# (2111, 17)

# %%
obesitydf
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %% [markdown]
# A large portion of features are categorical features.
# Listing the features and their attributes if categorical:

# %%
cols1= ['Gender', 'Age', 'Height', 'Weight','family_history_with_overweight', 'FAVC=Frequent consumption of high caloric food', 
            'FCVC - Frequency of consumption of vegetables','NCP - Number of main meals',
            'CAEC - Consumption of food between meals',
            'Smoke - Does the person smoke', 'CH2O - Consumption of water daily', 'SCC - Calories consumption monitoring',
            'FAF - Physical activity frequency', 'TUE - Time using technology devices', 'CALC - Consumption of alcoho', 
            'MTRANS - Transportation used', 'NObeyesdad - Obesity level']
cols2= ['Gender', 'Age', 'Height', 'Weight','family_history_with_overweight', 'FAVC', 'FCVC','NCP','CAEC','SMOKE', 'CH2O',
           'SCC', 'FAF', 'TUE', 'CALC', 
            'MTRANS', 'NObeyesdad']
i=0
for col in cols2:
  print(cols1[i])
  if obesitydf[col].nunique()<=7:
    print(obesitydf[col].unique())
  print('*************************************************')
  print("\n")
  i+=1
# Out:
# Gender
# ['Female' 'Male']
# *************************************************
#
#
# Age
# *************************************************
#
#
# Height
# *************************************************
#
#
# Weight
# *************************************************
#
#
# family_history_with_overweight
# ['yes' 'no']
# *************************************************
#
#
# FAVC=Frequent consumption of high caloric food
# ['no' 'yes']
# *************************************************
#
#
# FCVC - Frequency of consumption of vegetables
# *************************************************
#
#
# NCP - Number of main meals
# *************************************************
#
#
# CAEC - Consumption of food between meals
# ['Sometimes' 'Frequently' 'Always' 'no']
# *************************************************
#
#
# Smoke - Does the person smoke
# ['no' 'yes']
# *************************************************
#
#
# CH2O - Consumption of water daily
# ...

# %%
# The Age column is in float. IT worth if change it to integers!
obesitydf['Age'] = obesitydf['Age'].apply(int)
obesitydf
# Out:
#       Gender  Age    Height      Weight family_history_with_overweight FAVC  \
# 0     Female   21  1.620000   64.000000                            yes   no
# 1     Female   21  1.520000   56.000000                            yes   no
# 2       Male   23  1.800000   77.000000                            yes   no
# 3       Male   27  1.800000   87.000000                             no   no
# 4       Male   22  1.780000   89.800000                             no   no
# ...      ...  ...       ...         ...                            ...  ...
# 2106  Female   20  1.710730  131.408528                            yes  yes
# 2107  Female   21  1.748584  133.742943                            yes  yes
# 2108  Female   22  1.752206  133.689352                            yes  yes
# 2109  Female   24  1.739450  133.346641                            yes  yes
# 2110  Female   23  1.738836  133.472641                            yes  yes
#
# ...

# %%
obesitydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %% [markdown]
# since the number of non-null rows is equal to the number of total rows one concludes that there is no null value in any of the columns!

# %%
# checking for duplicated data
dup_obesitydf=obesitydf[obesitydf.duplicated()] 
dup_obesitydf.shape
# Out:
# (24, 17)

# %% [markdown]
# shows there are 24 duplicated data!

# %%
obesitydf = obesitydf.drop_duplicates(keep='last')
obesitydf = obesitydf.reset_index(drop=True)

# %% [markdown]
# Now the dataframe should be very clean!

# %%
obesitydf.nunique()
# Out:
# Gender                               2
# Age                                 40
# Height                            1574
# Weight                            1525
# family_history_with_overweight       2
# FAVC                                 2
# FCVC                               810
# NCP                                635
# CAEC                                 4
# SMOKE                                2
# CH2O                              1268
# SCC                                  2
# FAF                               1190
# TUE                               1129
# CALC                                 4
# MTRANS                               5
# NObeyesdad                           7
# dtype: int64

# %%
obesitydf.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2087.000000  2087.000000  2087.000000  2087.000000  2087.000000
# mean     24.009104     1.702674    86.858730     2.421466     2.701179
# std       6.333297     0.093186    26.190847     0.534737     0.764614
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.000000     1.630178    66.000000     2.000000     2.697467
# 50%      22.000000     1.701584    83.101100     2.396265     3.000000
# 75%      26.000000     1.769491   108.015907     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2087.000000  2087.000000  2087.000000
# mean      2.004749     1.012812     0.663035
# std       0.608284     0.853475     0.608153
# min       1.000000     0.000000     0.000000
# 25%       1.590922     0.124505     0.000000
# 50%       2.000000     1.000000     0.630866
# ...

# %% [markdown]
# The target variable is the last column (NObeyesdad) which shows the obesity level of people!

# %%
obesitydf['Gender'].value_counts()
# Out:
# Male      1052
# Female    1035
# Name: Gender, dtype: int64

# %%
plot1=obesitydf[obesitydf['Gender']=='Female']['NObeyesdad'].value_counts().plot(kind='bar',color=['red', 'green', 'blue', 'purple','yellow', 'pink', 'orange'])
plt.xlabel('Obesity Level',fontsize=17);
plt.ylabel('frequency',fontsize=17);
plot1.set_title('Obesity level among women', fontsize=18, y=1);

# %%
#colors = {"Obesity_Type_III": 'red', "Insufficient_Weight":'green', "Obesity_Type_I":'blue', "Overweight_Level_I":'yellow', "Normal_Weight":'purple', "Overweight_Level_II":'pink', "Obesity_Type_II":'orange'}
# The dictionary method did not work so I had to do it manually!

plot2=obesitydf[obesitydf['Gender']=='Male']['NObeyesdad'].value_counts().plot(kind='bar', color=['orange', 'blue', 'pink', 'yellow','purple', 'green', 'red'])
plt.xlabel('Obesity Level',fontsize=17);
plt.ylabel('Frequency',fontsize=17);
plot2.set_title('Obesity level among men', fontsize=18, y=1);

# %% [markdown]
# As shown in the graphs Obesity_Type III is very common between women but not common between men. However, Obesity_Type II is very common between men and not common between women!Another interesting result is that the ratio of the normal weight

# %%
sns.set(rc={'figure.figsize':(16,8)})
sns.set_style("white") 

plot3=sns.countplot(x="Age", data=obesitydf, palette=sns.color_palette("tab10"), saturation=2, hue='Gender')

plot3.axes.set_title("Age Distribution",fontsize=25)
plot3.set_xlabel("Age",fontsize=20)
plot3.set_ylabel("Count",fontsize=20)
plot3.tick_params(labelsize=15)

# %% [markdown]
# The age distribution i not balanced betweem males and females. This will have a negative impact on the prediciton modelling!

# %% [markdown]
# A large portion of features are categorical features.Belwo we list them!

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.set_style("white") 

plot3=sns.countplot(x="MTRANS", data=obesitydf, palette=sns.color_palette("Set2"), saturation=2, hue='Gender')

plot3.axes.set_title("Transportation Types",fontsize=25)
#plot3.set_xlabel("MTRANS",fontsize=20)
plot3.set_ylabel("Count",fontsize=20)
plot3.tick_params(labelsize=15)

# %%
sns.set(rc={'figure.figsize':(10,6)})
sns.set_style("white") 

plot4=sns.countplot(x="family_history_with_overweight", data=obesitydf, palette=sns.color_palette("Set2"), saturation=2, hue='Gender')

plot4.axes.set_title("Family history with overweight",fontsize=25)
plot4.set_xlabel("Overweight",fontsize=20)
plot4.set_ylabel("Count",fontsize=20)
plot4.tick_params(labelsize=15)

# %%
sns.set(rc={'figure.figsize':(10,6)})
sns.set_style("white") 

plot4=sns.countplot(x="FAVC", data=obesitydf, palette=sns.color_palette("Set2"), saturation=2, hue='Gender')

plot4.axes.set_title("Frequent consumption of high caloric food",fontsize=25)
plot4.set_xlabel("FAVC",fontsize=20)
plot4.set_ylabel("Count",fontsize=20)
plot4.tick_params(labelsize=15)

# %%
sns.set(rc={'figure.figsize':(10,6)})
sns.set_style("white") 

plot4=sns.countplot(x="CALC", data=obesitydf, palette=sns.color_palette("Set2"), saturation=2, hue='Gender')

plot4.axes.set_title("Consumption of alcohol",fontsize=25)
plot4.set_xlabel("CALC",fontsize=20)
plot4.set_ylabel("Count",fontsize=20)
plot4.tick_params(labelsize=15)

# %% [markdown]
# It is required to encode the categorical features in order to be able to use KNN method for Machine Learning!
# In this set of materials three different methods are used to encode the categorical variable. The reason is the need to manipulation of the codes.

# %%
replace_map={'NObeyesdad':{'Normal_Weight': 0, 'Overweight_Level_I': 1,'Overweight_Level_II': 2, 'Insufficient_Weight':-1, 'Obesity_Type_I' : 3  , 'Obesity_Type_II' : 4, 'Obesity_Type_III' : 5 }}
replace_map2={'CALC':{'no':0, 'Sometimes':1, 'Frequently':2, 'Always':3}}
replace_map3={'CAEC':{'no':0, 'Sometimes':1, 'Frequently':2, 'Always':3}}
replace_map4={'MTRANS':{'Walking':0, 'Public_Transportation':1, 'Automobile':2, 'Motorbike':2, 'Bike':2}}

# %%
obesitydf.replace(replace_map, inplace=True)
obesitydf.replace(replace_map2, inplace=True)
obesitydf.replace(replace_map3, inplace=True)
obesitydf.replace(replace_map4, inplace=True)

# %%
obesitydf.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#    CAEC SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS  NObeyesdad
# 0     1    no   2.0   no  0.0  1.0     0       1           0
# 1     1   yes   3.0  yes  3.0  0.0     1       1           0
# 2     1    no   2.0   no  2.0  1.0     2       1           0
# 3     1    no   2.0   no  2.0  0.0     2       0           1
# 4     1    no   2.0   no  0.0  0.0     1       1           2

# %%
 from sklearn.preprocessing import LabelEncoder
 lb_make = LabelEncoder()

# %%
list_of_cats=['SMOKE', 'FAVC', 'family_history_with_overweight', 'SCC']
for cat in list_of_cats:
    obesitydf[cat]=lb_make.fit_transform(obesitydf[cat])

# %%
obesitydf.head()
# Out:
#    Gender  Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0  Female   21    1.62    64.0                               1     0   2.0
# 1  Female   21    1.52    56.0                               1     0   3.0
# 2    Male   23    1.80    77.0                               1     0   2.0
# 3    Male   27    1.80    87.0                               0     0   3.0
# 4    Male   22    1.78    89.8                               0     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS  NObeyesdad
# 0  3.0     1      0   2.0    0  0.0  1.0     0       1           0
# 1  3.0     1      1   3.0    1  3.0  0.0     1       1           0
# 2  3.0     1      0   2.0    0  2.0  1.0     2       1           0
# 3  3.0     1      0   2.0    0  2.0  0.0     2       0           1
# 4  1.0     1      0   2.0    0  0.0  0.0     1       1           2

# %%
obesitydf_prep = pd.get_dummies(obesitydf,columns=["Gender"])

# %%
obesitydf_prep.head()
# Out:
#    Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  NCP  CAEC  \
# 0   21    1.62    64.0                               1     0   2.0  3.0     1
# 1   21    1.52    56.0                               1     0   3.0  3.0     1
# 2   23    1.80    77.0                               1     0   2.0  3.0     1
# 3   27    1.80    87.0                               0     0   3.0  3.0     1
# 4   22    1.78    89.8                               0     0   2.0  1.0     1
#
#    SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS  NObeyesdad  Gender_Female  \
# 0      0   2.0    0  0.0  1.0     0       1           0              1
# 1      1   3.0    1  3.0  0.0     1       1           0              1
# 2      0   2.0    0  2.0  1.0     2       1           0              0
# 3      0   2.0    0  2.0  0.0     2       0           1              0
# 4      0   2.0    0  0.0  0.0     1       1           2              0
#
#    Gender_Male
# 0            0
# 1            0
# 2            1
# ...

# %%
mean_corr=obesitydf_prep.corr()
fig, ax = plt.subplots(figsize=(14,10))
mask = np.zeros_like(mean_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
ax = sns.heatmap(mean_corr, mask=mask, ax=ax, annot=True, cmap='YlGnBu')
ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14)
ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14)
plt.show()
# Out:
# C:\Users\alima\AppData\Local\Temp\ipykernel_19696\2968534274.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(mean_corr, dtype=np.bool)

# %%
from matplotlib.colors import ListedColormap

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 20
x=obesitydf_prep['Weight']
y=obesitydf_prep['Height']
name=['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II', 'Obesity_Type_III']
cmap_bold = ListedColormap(['red', 'purple', 'blue',"darkorange", "gold", "lawngreen", "lightseagreen"])
plt.scatter(x, y, c=obesitydf_prep['NObeyesdad'], s=100, cmap=cmap_bold);
plt.xlabel('H', fontsize=20)
plt.ylabel('Weight', fontsize=20)
cbar=plt.colorbar()
cbar.ax.set_yticklabels(name, rotation=0, fontsize=14)
plt.show()
# Out:
# C:\Users\alima\AppData\Local\Temp\ipykernel_19696\54220043.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cbar.ax.set_yticklabels(name, rotation=0, fontsize=14)

# %% [markdown]
# As can be seen from the correlation coefficients between variables weight and family history have the strongest correlations with the obesity level, which makes sense!

# %% [markdown]
# ## ML with RandomForest and Knn methods

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import StratifiedKFold

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score

from sklearn.metrics import classification_report

from sklearn.model_selection import train_test_split

from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

# %% [markdown]
# # RandomForest

# %%
obesitydf_prep.columns.tolist()
# Out:
# ['Age',
#  'Height',
#  'Weight',
#  'family_history_with_overweight',
#  'FAVC',
#  'FCVC',
#  'NCP',
#  'CAEC',
#  'SMOKE',
#  'CH2O',
#  'SCC',
#  'FAF',
#  'TUE',
#  'CALC',
#  'MTRANS',
#  'NObeyesdad',
#  'Gender_Female',
#  'Gender_Male']

# %%
feature_cols=['Age','Height','Weight','family_history_with_overweight','FAVC','FCVC','NCP','CAEC','SMOKE','CH2O','SCC',
 'FAF','TUE','CALC','MTRANS','Gender_Female','Gender_Male']

# %%
X1=obesitydf_prep.drop(['NObeyesdad'], axis=1)
y=obesitydf_prep['NObeyesdad']

# %%
X1_train, X1_test, y_train, y_test=train_test_split(X1, y, test_size=0.30, random_state=42, stratify=y)

# %%
rfc=RandomForestClassifier(n_estimators=1000)
rfc.fit(X1_train, y_train)
rfc.score(X1_test, y_test)
# Out:
# 0.937799043062201

# %%
y_pred=rfc.predict(X1_test)

# %% [markdown]
# ## The model predicts correctly in 95% of cases, in average!

# %%
#calculating GIni importance of the feaures based and graphing them as bar graph!

importancedf=pd.DataFrame({'feature':feature_cols, 'importance':rfc.feature_importances_})
importancedf
# Out:
#                            feature  importance
# 0                              Age    0.079070
# 1                           Height    0.093857
# 2                           Weight    0.342000
# 3   family_history_with_overweight    0.036099
# 4                             FAVC    0.016097
# 5                             FCVC    0.082854
# 6                              NCP    0.049805
# 7                             CAEC    0.031411
# 8                            SMOKE    0.002778
# 9                             CH2O    0.043197
# 10                             SCC    0.004811
# 11                             FAF    0.043452
# 12                             TUE    0.047304
# 13                            CALC    0.032078
# 14                          MTRANS    0.019170
# 15                   Gender_Female    0.037500
# 16                     Gender_Male    0.038518

# %%
plt.bar(x=importancedf['feature'], height=importancedf['importance'], color='purple')
plt.title('Importances of the features', size=20)
plt.xticks(rotation='vertical', fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# This shows that Smoking and calory consumtion monitotring have the least effect ob the obesity level.

# %% [markdown]
# ## Knn Method

# %%
XX=obesitydf_prep.drop(['NObeyesdad'], axis=1)
ss=StandardScaler()
X=ss.fit_transform(XX)

# %%
y=obesitydf_prep['NObeyesdad']

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.30, random_state=42, stratify=y)

# %%
knn5=KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski', weights='distance', n_jobs=-1)

# %%
u=Knn5.fit(X_train, y_train)
y_pred = u.predict(X_test)

# %%
# Estimating the accuracy of the model!

skf=StratifiedKFold(n_splits=5)
cv_indices=skf.split(X,y)
cv_indices=[[tr,te] for tr, te in cv_indices]
def accuracy_crossvalidator(X, y, knn, cv_indices):
    scores=[]
    for train_i, test_i in cv_indices:
        X_train = X[train_i, :]
        X_test = X[test_i, :]
        Y_train = y[train_i]
        Y_test = y[test_i]
        knn.fit(X_train, Y_train)
        acc = knn.score(X_test, Y_test)
        scores.append(acc)
        print(('Fold accuracy:', acc))
    print(('Mean CV accuracy:', np.mean(scores)))
    return 
knn5=KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski', weights='distance', n_jobs=-1)
accuracy_crossvalidator(X, y, knn5, cv_indices)
# Out:
# ('Fold accuracy:', 0.6339712918660287)
# ('Fold accuracy:', 0.8397129186602871)
# ('Fold accuracy:', 0.8561151079136691)
# ('Fold accuracy:', 0.8609112709832134)
# ('Fold accuracy:', 0.8992805755395683)
# ('Mean CV accuracy:', 0.8179982329925533)

# %% [markdown]
# ## The model predicts correctly in 82% of cases, in average!
